# %% [markdown]
# Functions
#     use def [function name] (inputs, inputs):
#     """
#     Explain function
#         Ex:
#     """
#     write equation
#     return [variable]
#     print ([function name(input variables)
#
# y = lambda var1, var2: x + y
# print(y(input1, input2))
#
# lambda makes it an anonymous function and you don't have to define it
# lambda has to be simple because it should only span one line
#
# Lists
#     You can store variable names, prices, wages, income, variables
#
#     depths = [1, 5, 3, 6, 4, 7, 10, 12]
#     first_5_depths = depths[:5]
#                             takes from very beginning [0 is 1] [:5] means start from the beginning to 5
#
#     [:5:2] :2 is every other
#     print(22 in depths) check to see if 22 is in list
#     depths.append(44)
#         will add 44 to end of list
#     depths[4] = 100
#         change 4th one to 100
#
#     shift tab will give you example
#
# Dictionaries
#     key, value pairs
#     gives named things
#     assume that you don't care about order, puts in any order
#
# Tuples
#     two things in parenthesis
#
#     Ex: x, y = (5, 2)
#     z = (5,2)
#
# Default dictionaries
#     not really sure
#
# Sets
#     unordered collection of unique and immutable objects
#     prevents duplicates
#     shows the different results
#
# If, then statements
#     elif means "else if" (should be put after an if statement)
#     put most common thing at the top
#     be careful with putting else because you may not have thought of all the options
#
# For loops
#     start from 0
#     look up what this is
#
#     enumerate loops your list into tuples (puts loop value for each value)
#
# Sorting
#     my_list.sort will order the list
#
#     how to use key=[funtion]
#
# List Comprehensions
#     try to understand what a for loop
#
# Zipping
#     combine two lists into a tuple
#     you can unzip things
#     separate tuples into two lists
#
#
# Counter
#     ?Counter explains function
